# %% [markdown]
# # QuantLux Trading Analysis
# This notebook provides an environment to analyze trade history and performance.

# %%
from setup_notebook import init_env

settings, logger = init_env()

# %%
from app.engine.lifecycle import init_storage

storage = await init_storage()
trades = await storage.get_all()
print(f"Loaded {len(trades)} trades.")
